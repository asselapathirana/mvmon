# %%
import pandas as pd

# %%
df=pd.read_pickle('./data/all_stations_data.pkl').reset_index()
df.columns
# Out:
# Index(['index', 'REC_TIME', 'UNIT_ID', 'H1', 'H0', 'V', 'T0', 'T1', 'C1',
#        'ERR', 'H2', 'T2', 'R', 'Rr', 'L0', 'L1'],
#       dtype='object')

# %%
# select only station A07, dates from 2023-09-13 to 2023-09-15
dft=df[(df['UNIT_ID']=='A07') & (df['REC_TIME']>=pd.to_datetime('2023-09-13')) & (df['REC_TIME']<=pd.to_datetime('2023-09-16'))]
dft[:50]
# Out:
#        index            REC_TIME UNIT_ID  H1  H0   V  T0  T1  C1  ERR  H2  T2  \
# 19012  19012 2023-09-13 01:00:00     A07 NaN NaN NaN NaN NaN NaN  0.0 NaN NaN
# 19013  19013 2023-09-13 02:00:00     A07 NaN NaN NaN NaN NaN NaN  0.0 NaN NaN
# 19014  19014 2023-09-13 03:00:00     A07 NaN NaN NaN NaN NaN NaN  0.0 NaN NaN
# 19015  19015 2023-09-13 04:00:00     A07 NaN NaN NaN NaN NaN NaN  0.0 NaN NaN
# 19016  19016 2023-09-13 05:00:00     A07 NaN NaN NaN NaN NaN NaN  0.0 NaN NaN
# 19017  19017 2023-09-13 06:00:00     A07 NaN NaN NaN NaN NaN NaN  0.0 NaN NaN
# 19018  19018 2023-09-13 07:00:00     A07 NaN NaN NaN NaN NaN NaN  0.0 NaN NaN
# 19019  19019 2023-09-13 08:00:00     A07 NaN NaN NaN NaN NaN NaN  0.0 NaN NaN
# 19020  19020 2023-09-13 09:00:00     A07 NaN NaN NaN NaN NaN NaN  0.0 NaN NaN
# 19021  19021 2023-09-13 10:00:00     A07 NaN NaN NaN NaN NaN NaN  0.0 NaN NaN
# 19022  19022 2023-09-13 11:00:00     A07 NaN NaN NaN NaN NaN NaN  0.0 NaN NaN
# ...

# %%
# select only station A07, dates from 2023-09-13 to 2023-09-15
dft2=df[(df['UNIT_ID']=='A03') & (df['REC_TIME']>=pd.to_datetime('2023-09-13')) & (df['REC_TIME']<=pd.to_datetime('2023-09-16'))]
dft2[:50]
# Out:
#       index            REC_TIME UNIT_ID    H1     H0      V     T0     T1  \
# 7026   7026 2023-09-13 01:00:00     A03  0.95  10.24  15.87  27.69  27.90
# 7027   7027 2023-09-13 02:00:00     A03  0.95  10.24  15.79  27.59  27.91
# 7028   7028 2023-09-13 03:00:00     A03  0.93  10.23  15.80  27.47  27.91
# 7029   7029 2023-09-13 04:00:00     A03  0.87  10.23  15.78  27.14  27.92
# 7030   7030 2023-09-13 05:00:00     A03  0.82  10.22  15.75  26.39  27.92
# 7031   7031 2023-09-13 06:00:00     A03  0.75  10.23  15.74  26.47  27.93
# 7032   7032 2023-09-13 07:00:00     A03  0.70  10.24  15.74  28.32  27.94
# 7033   7033 2023-09-13 08:00:00     A03  0.68  10.26  15.95  31.87  27.94
# 7034   7034 2023-09-13 09:00:00     A03  0.68  10.28  16.10  38.07  27.94
# 7035   7035 2023-09-13 10:00:00     A03  0.74  10.29  16.16  39.24  27.95
# 7036   7036 2023-09-13 11:00:00     A03  0.83  10.28  16.16  38.24  27.95
# 7037   7037 2023-09-13 12:00:00     A03  0.91  10.27  16.16  37.15  27.97
# ...
